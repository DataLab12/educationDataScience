# %% [markdown]
# # EDA for Average Daily Attendance Data

# %% [markdown]
# ***Import libraries:***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Let's make sure we have the data in this folder, in order to read it in properly...

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is CAE1-C318
#
#  Directory of C:\Users\Daniel Payan\Documents\ML\d_p327\Project\data
#
# 11/28/2022  05:55 PM    <DIR>          .
# 11/28/2022  05:55 PM    <DIR>          ..
# 11/28/2022  05:55 PM    <DIR>          .ipynb_checkpoints
# 11/18/2022  05:21 PM         4,759,702 3grade_STAAR.dat
# 11/18/2022  05:21 PM         4,758,314 4grade_STAAR.dat
# 11/18/2022  05:22 PM         7,292,662 5grade_STAAR.dat
# 11/18/2022  05:22 PM         4,783,506 6grade_STAAR.dat
# 11/18/2022  05:22 PM         4,749,172 7grade_STAAR.dat
# 11/18/2022  05:22 PM         9,696,589 8grade_STAAR.dat
# 09/25/2022  04:24 PM            38,243 ada_cleaning.ipynb
# 09/25/2022  04:24 PM            31,589 ada_cleaning_v2.ipynb
# 11/28/2022  05:25 PM           325,288 ada_district.csv
# 11/18/2022  07:05 PM         4,263,746 Census_Block_Group_2010_TX.csv
# 09/25/2022  04:24 PM            14,259 Census_Block_Group_2010_TX_cleaning.ipynb
# 09/25/2022  04:24 PM            63,073 Covid Cleaning County Level.ipynb
# 11/28/2022  05:30 PM        15,106,051 covid_confirmed_usafacts.csv
# 11/28/2022  05:31 PM            98,761 covid_county_population_usafacts.csv
# 11/28/2022  05:30 PM        10,021,985 covid_deaths_usafacts.csv
# 09/25/2022  04:24 PM            53,533 DATA_ESSER_DISTRICT.csv
# 09/25/2022  04:24 PM            32,205 DATA_LAUS_COUNTY.csv
# 09/25/2022  04:24 PM           449,543 DATA_NCES_DISTRICT.csv
# 09/25/2022  04:24 PM           482,719 DATA_NCES_DISTRICT_v3.csv
# 08/03/2022  06:50 PM         3,973,779 DATA_STAAR_DISTRICT_2019.csv
# 08/03/2022  06:50 PM         3,829,206 DATA_STAAR_DISTRICT_2021.csv
# 11/28/2022  03:35 PM         1,295,453 DATA_STAAR_DISTRICT_2022.csv
# 07/19/2022  09:44 AM            23,116 staar_labels.csv
#               23 File(s)     76,142,494 bytes
#                3 Dir(s)  11,641,073,664 bytes free

# %% [markdown]
# ***Data Reading:***

# %%
# read in the csv file
df_d = pd.read_excel('ada_district.xlsx')

df_d
# Out:
#       County      County Name  District      District Name   2004-2005 ADA  \
# 0          1  ANDERSON COUNTY      1902         CAYUGA ISD         552.283
# 1          1  ANDERSON COUNTY      1903        ELKHART ISD        1162.821
# 2          1  ANDERSON COUNTY      1904      FRANKSTON ISD         749.499
# 3          1  ANDERSON COUNTY      1906         NECHES ISD         299.036
# %%
df_d.drop(columns = [' 2004-2005 ADA', \
                      ' 2005-2006 ADA', \
                      ' 2006-2007 ADA', \
                      '2007-2008 ADA', \
                      '2008-2009 ADA', \
                      ' 2009-2010 ADA', \
                      '2010-2011 ADA', \
                      ' 2011-2012 ADA', \
                      ' 2012-2013 ADA', \
                      ' 2013-2014 ADA', \
                      ' 2014-2015 ADA', \
                      ' 2015-2016 ADA', \
                      ' 2016-2017 ADA'], inplace = True)

df_d.replace(',','', regex=True, inplace=True)
df_d['District #'] = df_d['District']
df_d[' 2017-2018 ADA']= df_d[' 2017-2018 ADA'].astype(float)
df_d[' 2018-2019 ADA']= df_d[' 2017-2018 ADA'].astype(float)
df_d[' 2019-2020 ADA']= df_d[' 2017-2018 ADA'].astype(float)
df_d[' 2020-2021 ADA']= df_d[' 2017-2018 ADA'].astype(float)
df_d[' 2021-2022 ADA']= df_d[' 2017-2018 ADA'].asty
df_d.dropna(inplace = True)
zeros = df_d[df_d[' 2017-2018 ADA'] == 0]
df_d.drop(zeros.index, inplace=True)

df_d['2017-2018 ADA']= df_d[' 2017-2018 ADA']
df_d['2018-2019 ADA']= df_d[' 2018-2019 ADA']
df_d['2019-2020 ADA']= df_d[' 2019-2020 ADA']
df_d['2020-2021 ADA']= df_d[' 2020-2021 ADA']

df_d.drop(columns = [' 2017-2018 ADA', \
                     ' 2018-2019 ADA', \
                     ' 2019-2020 ADA', \
                     ' 2020-2021 ADA'], inplace = True)
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1206 entries, 0 to 1406
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   County         1206 non-null   int64
#  1   County Name    1206 non-null   object
#  2   District       1206 non-null   int64
#  3   District Name  1206 non-null   object
#  4   District #     1206 non-null   int64
#  5   2017-2018 ADA  1206 non-null   float64
#  6   2018-2019 ADA  1206 non-null   float64
#  7   2019-2020 ADA  1206 non-null   float64
#  8   2020-2021 ADA  1206 non-null   float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 94.2+ KB

# %%
df_d.to_csv('DATA_ADA_DISTRICT.csv', index = None)

# %%
# read in the csv file
df_c = pd.read_csv('ada data/ada_county.csv')

df_c.drop(columns = [' 2004-2005 ADA', \
                    ' 2005-2006 ADA', \
                    ' 2006-2007 ADA', \
                    '2007-2008 ADA', \
                    '2008-2009 ADA', \
                    ' 2009-2010 ADA', \
                    '2010-2011 ADA', \
                    ' 2011-2012 ADA', \
                    ' 2012-2013 ADA', \
                    ' 2013-2014 ADA', \
                    ' 2014-2015 ADA', \
                    ' 2015-2016 ADA', \
                    ' 2016-2017 ADA'], inplace = True)

df_c
# Out:
#      County      County Name  2017-2018 ADA  2018-2019 ADA  2019-2020 ADA  \
# 0         1  ANDERSON COUNTY       7,786.97       7,690.77       7,340.51
# 1         2   ANDREWS COUNTY       3,840.23       4,085.36       4,064.98
# 2         3  ANGELINA COUNTY      15,973.61      15,763.88      15,282.64
# 3         4   ARANSAS COUNTY       3,192.18       2,641.35       2,680.59
# 4         5    ARCHER COUNTY       1,806.48       1,839.82       1,826.43
# ..      ...              ...            ...            ...            ...
# 248     250      WOOD COUNTY       5,820.52       5,787.86       5,583.89
# 249     251    YOAKUM COUNTY       1,995.59       2,024.96       1,966.94
# 250     252     YOUNG COUNTY       3,062.38       3,098.99       2,859.72
# 251     253    ZAPATA COUNTY       3,077.73       3,117.64       2,933.07
# 252     254    ZAVALA COUNTY       2,195.63       2,213.47       2,081.81
#
#      2020-2021 ADA
# 0         7213.337
# 1         4068.126
# 2        14801.498
# 3         2681.159
# 4         1884.252
# ..             ...
# 248       5724.323
# 249       1936.490
# 250       3009.943
# 251       2961.206
# 252       2035.699
#
# [253 rows x 6 columns]

# %%
columns = ['County', 'County Name', 'County #', 'Public Health Region', 'Health Service Region']

cc = pd.read_csv('ada data/county_conversion.csv', names = columns, header = 0)

cc.drop(columns = ['Public Health Region', 'Health Service Region', 'County Name'], inplace = True)

cc
# Out:
#      County  County #
# 0         1     48001
# 1         2     48003
# 2         3     48005
# 3         4     48007
# 4         5     48009
# ..      ...       ...
# 249     250     48499
# 250     251     48501
# 251     252     48503
# 252     253     48505
# 253     254     48507
#
# [254 rows x 2 columns]

# %%
df_c = df_c.merge(cc, how = "inner", on = "County")

# %%
df_c
# Out:
#      County      County Name  2017-2018 ADA  2018-2019 ADA  2019-2020 ADA  \
# 0         1  ANDERSON COUNTY       7,786.97       7,690.77       7,340.51
# 1         2   ANDREWS COUNTY       3,840.23       4,085.36       4,064.98
# 2         3  ANGELINA COUNTY      15,973.61      15,763.88      15,282.64
# 3         4   ARANSAS COUNTY       3,192.18       2,641.35       2,680.59
# 4         5    ARCHER COUNTY       1,806.48       1,839.82       1,826.43
# ..      ...              ...            ...            ...            ...
# 248     250      WOOD COUNTY       5,820.52       5,787.86       5,583.89
# 249     251    YOAKUM COUNTY       1,995.59       2,024.96       1,966.94
# 250     252     YOUNG COUNTY       3,062.38       3,098.99       2,859.72
# 251     253    ZAPATA COUNTY       3,077.73       3,117.64       2,933.07
# 252     254    ZAVALA COUNTY       2,195.63       2,213.47       2,081.81
#
#      2020-2021 ADA  County #
# 0         7213.337     48001
# 1         4068.126     48003
# 2        14801.498     48005
# 3         2681.159     48007
# 4         1884.252     48009
# ..             ...       ...
# 248       5724.323     48499
# 249       1936.490     48501
# 250       3009.943     48503
# 251       2961.206     48505
# 252       2035.699     48507
#
# [253 rows x 7 columns]

# %%
df_c.to_csv('DATA_ADA_COUNTY.csv', index = None)
