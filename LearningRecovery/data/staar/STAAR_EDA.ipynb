# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
staar22_df = pd.read_csv('data/DATA_STAAR_DISTRICT_2022.csv')
staar21_df = pd.read_csv('data/DATA_STAAR_DISTRICT_2021.csv')
staar19_df = pd.read_csv('data/DATA_STAAR_DISTRICT_2019.csv')

# %%
staar22_df
# Out:
#       District #  r_all_d_g3_2022  r_ethh_d_g3_2022  r_etha_d_g3_2022  \
# 0           1902             40.0               6.0               0.0
# 1           1903             85.0              10.0               0.0
# 2           1904             61.0               7.0               1.0
# 3           1906             20.0               1.0               0.0
# 4           1907            221.0              78.0               2.0
# ...          ...              ...               ...               ...
# 1180       72801              NaN               NaN               NaN
# 1181       72802              NaN               NaN               NaN
# 1182      227622              NaN               NaN               NaN
# 1183      111801              NaN               NaN               NaN
# 1184      183801              NaN               NaN               NaN
#
#       r_ethb_d_g3_2022  r_ethw_d_g3_2022  r_ecoy_d_g3_2022  r_eco1_d_g3_2022  \
# ...

# %%
staar21_df
# Out:
#       DNAME_g3_2021  r_all_rs_g3_2021  r_ti1y_rs_g3_2021  r_ecoy_rs_g3_2021  \
# 0        CAYUGA ISD            1523.0             1523.0             1486.0
# 1       ELKHART ISD            1463.0             1463.0             1416.0
# 2     FRANKSTON ISD            1504.0             1504.0             1453.0
# 3        NECHES ISD            1474.0             1474.0             1416.0
# 4     PALESTINE ISD            1401.0             1401.0             1382.0
# ...             ...               ...                ...                ...
# 3196            NaN               NaN                NaN                NaN
# 3197            NaN               NaN                NaN                NaN
# 3198            NaN               NaN                NaN                NaN
# 3199            NaN               NaN                NaN                NaN
# 3200            NaN               NaN                NaN                NaN
#
# ...

# %%
staar19_df
# Out:
#       DNAME_g3_2019  r_all_d_g3_2019  r_ethh_d_g3_2019  r_etha_d_g3_2019  \
# 0        CAYUGA ISD             46.0               3.0               0.0
# 1       ELKHART ISD             94.0              10.0               0.0
# 2       ELKHART ISD             94.0              10.0               0.0
# 3     FRANKSTON ISD             55.0               5.0               1.0
# 4        NECHES ISD             25.0               5.0               0.0
# ...             ...              ...               ...               ...
# 3305            NaN              NaN               NaN               NaN
# 3306            NaN              NaN               NaN               NaN
# 3307            NaN              NaN               NaN               NaN
# 3308            NaN              NaN               NaN               NaN
# 3309            NaN              NaN               NaN               NaN
#
#       r_ethb_d_g3_2019  r_ethw_d_g3_2019  r_ecoy_d_g3_2019  r_eco1_d_g3_2019  \
# ...
